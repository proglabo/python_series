# %% [markdown]
# # LSTM
#
# 長・短期記憶(Long short-term memory)と呼ばれます。
#
# 深層学習（ディープラーニング）の分野において用いられる再帰型ニューラルネットワーク（RNN）の1種です。
#
# LSTMは、従来のRNNでは難しかった、より昔のデータまでを考慮した学習が可能です。
#
# <img src="./images/LSTM.png" width="80%" style="position:relative;left:-10%;">
#
# 引用：https://qiita.com/t_Signull/items/21b82be280b46f467d1b

# %%
# ライブラリの読み込みと各種設定
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
# グラフの日本語設定
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']
plt.rcParams['figure.figsize'] = 20, 5

# %% [markdown]
# ## データの読み込み
#
# 今回使用するデータは、気温の時系列データです。
#
# データ配布元：http://www.data.jma.go.jp/gmd/risk/obsdl/index.php
#
# **まずは、理解を容易にするため、気温データのみを用います**

# %%
weather_df = pd.read_csv("./data/weather.csv", index_col='年月日', encoding="shift-jis")

# %%
weather_df
# Out:
#             平均気温(℃)  降水量の合計(mm)  平均風速(m/s)  日照時間(時間)  平均現地気圧(hPa)
# 年月日
# 2015/1/1        3.7         0.0        4.4       1.3       1000.4
# 2015/1/2        2.7         0.0        2.1       6.0       1007.4
# 2015/1/3        3.8         0.0        3.0       8.9       1012.0
# 2015/1/4        4.0         0.0        1.3       6.0       1010.4
# 2015/1/5        6.9         0.0        2.4       8.9       1014.6
# ...             ...         ...        ...       ...          ...
# 2019/12/28      6.8         0.0        3.5       8.8       1019.9
# 2019/12/29      7.0         0.0        1.9       8.3       1026.5
# 2019/12/30      6.7         0.5        1.8       0.0       1021.0
# 2019/12/31      8.2         0.0        3.6       8.6       1009.1
# 2020/1/1        5.5         0.0        2.6       7.4       1018.0
#
# [1827 rows x 5 columns]

# %% [markdown]
# ## データの作成
#
# 説明変数と目的変数を作っていきます。
#
# 説明変数は、時刻(t-p) ~ 時刻(t-1)までの範囲
#
# ＊p:単位時間×任意の長さ→どこまで昔のデータを使用したいか
#
# 目的変数は、時刻(t)での値

# %%
# 説明変数を格納
data_X = []
# 目的変数を格納
data_y = []
# 時数（どこまで過去のデータを考慮したいか）
p = 10
for i in range(len(weather_df)-p):
    data_X.append(weather_df['平均気温(℃)'][i:i+p])
    data_y.append(weather_df['平均気温(℃)'][i+p])
    
data_X = np.array(data_X)
data_y = np.array(data_y)

# %%
# 訓練データとテストデータに分けます。
len_train = int(len(data_X)*0.7)

X_train = data_X[:len_train]
X_test = data_X[len_train:]
y_train = data_y[:len_train]
y_test = data_y[len_train:]

print(len(X_train),len(X_test))
# Out:
# 1271 546

# %%
# 正規化（Normarization）
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler()
X_train_n = scaler_x.fit_transform(X_train)
X_test_n = scaler_x.transform(X_test) 
scaler_y = MinMaxScaler()
y_train_n = scaler_y.fit_transform(y_train.reshape(len(y_train),1))
y_test_n = scaler_y.transform(y_test.reshape(len(y_test),1))

# %%
# 現在のデータ形式
print(X_train.shape,X_test.shape)
# Out:
# (1271, 10) (546, 10)

# %% [markdown]
# ## データ形式の変更
#
# 上記で見た通り、（データ数, 説明変数の数）の形式になっていますが、
#
# これを、（データ数, 系列数, 説明変数の数）に変更してやる必要があります。
#
# ＊系列数：扱う時系列データの種類数
#
# 今回は、「気温」だけ扱うので、系列数＝1で大丈夫ですが、「気温」「湿度」など複数の時系列データを扱う際は、その数に応じた数値を指定してやる必要があります。

# %%
X_train_n = np.reshape(X_train_n, (X_train_n.shape[0], 1, X_train_n.shape[1]))
X_test_n = np.reshape(X_test_n, (X_test_n.shape[0], 1, X_test_n.shape[1]))

# %% [markdown]
# ## モデルの実装
#
# データの準備が整いましたので、モデルを「作成→学習→予測」していきます

# %%
from keras.layers import LSTM,Dense
from keras import models

# %%
# 時数（どこまで過去のデータを考慮したいか）
p = 10

# モデル定義
model = models.Sequential()
model.add(
    LSTM(
        100, 
        activation='tanh', 
        input_shape=(1, p)
    )
)
model.add(Dense(1,activation='linear'))

# 学習設定
model.compile(
    loss='mean_squared_error', 
    optimizer='adam'
)

# %%
# モデルの学習
result = model.fit(
    X_train_n, 
    y_train_n, 
    batch_size=10, 
    epochs=100
)
# Out:
# Epoch 1/100
# 1271/1271 [==============================] - 1s 581us/step - loss: 0.0271
# Epoch 2/100
# 1271/1271 [==============================] - 0s 289us/step - loss: 0.0062
# Epoch 3/100
# 1271/1271 [==============================] - 0s 229us/step - loss: 0.0058
# Epoch 4/100
# 1271/1271 [==============================] - 0s 235us/step - loss: 0.0054
# Epoch 5/100
# 1271/1271 [==============================] - 0s 185us/step - loss: 0.0051
# Epoch 6/100
# 1271/1271 [==============================] - 0s 184us/step - loss: 0.0049
# Epoch 7/100
# 1271/1271 [==============================] - 0s 190us/step - loss: 0.0048
# Epoch 8/100
# 1271/1271 [==============================] - 0s 185us/step - loss: 0.0046
# Epoch 9/100
# 1271/1271 [==============================] - 0s 281us/step - loss: 0.0045
# Epoch 10/100
# 1271/1271 [==============================] - 0s 206us/step - loss: 0.0044
# Epoch 11/100
# 1271/1271 [==============================] - 0s 175us/step - loss: 0.0044
# Epoch 12/100
# 1271/1271 [==============================] - 0s 222us/step - loss: 0.0043
# Epoch 13/100
# 1271/1271 [==============================] - 0s 268us/step - loss: 0.0043
# Epoch 14/100
# 1271/1271 [==============================] - 0s 185us/step - loss: 0.0043
# Epoch 15/100
# 1271/1271 [==============================] - 0s 263us/step - loss: 0.0041
# Epoch 16/100
# 1271/1271 [==============================] - 0s 165us/step - loss: 0.0045
# Epoch 17/100
# 1271/1271 [==============================] - 0s 146us/step - loss: 0.0041
# Epoch 18/100
# 1271/1271 [==============================] - 0s 157us/step - loss: 0.0042
# Epoch 19/100
# 1271/1271 [==============================] - 0s 155us/step - loss: 0.0044
# Epoch 20/100
# 1271/1271 [==============================] - 0s 219us/step - loss: 0.0041
# Epoch 21/100
# 1271/1271 [==============================] - 0s 158us/step - loss: 0.0041
# Epoch 22/100
# 1271/1271 [==============================] - 0s 215us/step - loss: 0.0041
# Epoch 23/100
# 1271/1271 [==============================] - 0s 255us/step - loss: 0.0040
# Epoch 24/100
# 1271/1271 [==============================] - 0s 206us/step - loss: 0.0041
# Epoch 25/100
# 1271/1271 [==============================] - 0s 240us/step - loss: 0.0040
# Epoch 26/100
# 1271/1271 [==============================] - 0s 213us/step - loss: 0.0041
# Epoch 27/100
# 1271/1271 [==============================] - 0s 176us/step - loss: 0.0043
# Epoch 28/100
# 1271/1271 [==============================] - 0s 177us/step - loss: 0.0041
# Epoch 29/100
# 1271/1271 [==============================] - 0s 177us/step - loss: 0.0041
# Epoch 30/100
# 1271/1271 [==============================] - 0s 169us/step - loss: 0.0042
# Epoch 31/100
# 1271/1271 [==============================] - 0s 156us/step - loss: 0.0041
# Epoch 32/100
# 1271/1271 [==============================] - 0s 192us/step - loss: 0.0042
# Epoch 33/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0040
# Epoch 34/100
# 1271/1271 [==============================] - 0s 172us/step - loss: 0.0041
# Epoch 35/100
# 1271/1271 [==============================] - 0s 155us/step - loss: 0.0040
# Epoch 36/100
# 1271/1271 [==============================] - 0s 158us/step - loss: 0.0040
# Epoch 37/100
# 1271/1271 [==============================] - 0s 160us/step - loss: 0.0041
# Epoch 38/100
# 1271/1271 [==============================] - 0s 169us/step - loss: 0.0040
# Epoch 39/100
# 1271/1271 [==============================] - 0s 250us/step - loss: 0.0040
# Epoch 40/100
# 1271/1271 [==============================] - 0s 270us/step - loss: 0.0040
# Epoch 41/100
# 1271/1271 [==============================] - 0s 333us/step - loss: 0.0041
# Epoch 42/100
# 1271/1271 [==============================] - 0s 294us/step - loss: 0.0040
# Epoch 43/100
# 1271/1271 [==============================] - 0s 204us/step - loss: 0.0042
# Epoch 44/100
# 1271/1271 [==============================] - 0s 238us/step - loss: 0.0041
# Epoch 45/100
# 1271/1271 [==============================] - 0s 242us/step - loss: 0.0040
# Epoch 46/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0041
# Epoch 47/100
# 1271/1271 [==============================] - 0s 198us/step - loss: 0.0041
# Epoch 48/100
# 1271/1271 [==============================] - 0s 221us/step - loss: 0.0040
# Epoch 49/100
# 1271/1271 [==============================] - ETA: 0s - loss: 0.004 - 0s 189us/step - loss: 0.0040
# Epoch 50/100
# 1271/1271 [==============================] - 0s 200us/step - loss: 0.0040
# Epoch 51/100
# 1271/1271 [==============================] - 0s 204us/step - loss: 0.0040
# Epoch 52/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0040
# Epoch 53/100
# 1271/1271 [==============================] - 0s 196us/step - loss: 0.0042
# Epoch 54/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0041
# Epoch 55/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0040
# Epoch 56/100
# 1271/1271 [==============================] - 0s 227us/step - loss: 0.0040
# Epoch 57/100
# 1271/1271 [==============================] - 0s 240us/step - loss: 0.0042
# Epoch 58/100
# 1271/1271 [==============================] - 0s 219us/step - loss: 0.0041
# Epoch 59/100
# 1271/1271 [==============================] - 0s 215us/step - loss: 0.0040
# Epoch 60/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0040
# Epoch 61/100
# 1271/1271 [==============================] - 0s 200us/step - loss: 0.0039
# Epoch 62/100
# 1271/1271 [==============================] - 0s 192us/step - loss: 0.0041
# Epoch 63/100
# 1271/1271 [==============================] - 0s 197us/step - loss: 0.0040
# Epoch 64/100
# 1271/1271 [==============================] - 0s 193us/step - loss: 0.0040
# Epoch 65/100
# 1271/1271 [==============================] - 0s 221us/step - loss: 0.0041
# Epoch 66/100
# 1271/1271 [==============================] - 0s 242us/step - loss: 0.0040
# Epoch 67/100
# 1271/1271 [==============================] - 0s 210us/step - loss: 0.0040
# Epoch 68/100
# 1271/1271 [==============================] - 0s 186us/step - loss: 0.0040
# Epoch 69/100
# 1271/1271 [==============================] - 0s 193us/step - loss: 0.0040
# Epoch 70/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0039
# Epoch 71/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0040
# Epoch 72/100
# 1271/1271 [==============================] - 0s 191us/step - loss: 0.0042
# Epoch 73/100
# 1271/1271 [==============================] - 0s 194us/step - loss: 0.0040
# Epoch 74/100
# 1271/1271 [==============================] - 0s 196us/step - loss: 0.0040
# Epoch 75/100
# 1271/1271 [==============================] - 0s 208us/step - loss: 0.0040
# Epoch 76/100
# 1271/1271 [==============================] - 0s 181us/step - loss: 0.0040
# Epoch 77/100
# 1271/1271 [==============================] - 0s 189us/step - loss: 0.0040
# Epoch 78/100
# 1271/1271 [==============================] - 0s 190us/step - loss: 0.0041
# Epoch 79/100
# 1271/1271 [==============================] - 0s 201us/step - loss: 0.0039
# Epoch 80/100
# 1271/1271 [==============================] - 0s 242us/step - loss: 0.0040
# Epoch 81/100
# 1271/1271 [==============================] - 0s 274us/step - loss: 0.0041
# Epoch 82/100
# 1271/1271 [==============================] - 0s 277us/step - loss: 0.0041
# Epoch 83/100
# 1271/1271 [==============================] - 0s 265us/step - loss: 0.0039
# Epoch 84/100
# 1271/1271 [==============================] - 0s 179us/step - loss: 0.0040
# Epoch 85/100
# 1271/1271 [==============================] - 0s 201us/step - loss: 0.0042
# Epoch 86/100
# 1271/1271 [==============================] - 0s 168us/step - loss: 0.0040
# Epoch 87/100
# 1271/1271 [==============================] - 0s 157us/step - loss: 0.0039
# Epoch 88/100
# 1271/1271 [==============================] - 0s 160us/step - loss: 0.0041
# Epoch 89/100
# 1271/1271 [==============================] - 0s 174us/step - loss: 0.0040
# Epoch 90/100
# 1271/1271 [==============================] - 0s 184us/step - loss: 0.0041
# Epoch 91/100
# 1271/1271 [==============================] - 0s 145us/step - loss: 0.0040
# Epoch 92/100
# 1271/1271 [==============================] - 0s 165us/step - loss: 0.0041
# Epoch 93/100
# 1271/1271 [==============================] - 0s 166us/step - loss: 0.0041
# Epoch 94/100
# 1271/1271 [==============================] - 0s 164us/step - loss: 0.0041
# Epoch 95/100
# 1271/1271 [==============================] - 0s 222us/step - loss: 0.0039
# Epoch 96/100
# 1271/1271 [==============================] - 0s 256us/step - loss: 0.0040
# Epoch 97/100
# 1271/1271 [==============================] - 0s 268us/step - loss: 0.0040
# Epoch 98/100
# 1271/1271 [==============================] - 0s 224us/step - loss: 0.0041
# Epoch 99/100
# 1271/1271 [==============================] - 0s 184us/step - loss: 0.0039
# Epoch 100/100
# 1271/1271 [==============================] - 0s 177us/step - loss: 0.0041

# %%
# 予測値の算出
y_prediction_n = model.predict(X_test_n)
# 正規化の復元
y_prediction = scaler_y.inverse_transform(y_prediction_n).flatten()

# %%
plt.plot(y_prediction, label='予測値')
plt.plot(y_test, label='実測値')
plt.legend()

# %%
# 乖離度
print(
    np.mean(
        np.abs(y_prediction-y_test)
        /y_test
    )
)
# Out:
# 0.13466103916454558

# %% [markdown]
# # 複雑なモデルの実装
#
# 前述のモデルは、過去の「気温」のみのデータを用いて、未来の「気温」を予測しましたが、
#
# 次は、過去の「気温」「気圧」のみのデータを用いて、未来の「気温」「気圧」を予測してみます。

# %% [markdown]
# ## データの作成

# %%
# 正規化（Normarization）
from sklearn.preprocessing import MinMaxScaler
scaler_x1 = MinMaxScaler()
x1 = scaler_x1.fit_transform(weather_df['平均気温(℃)'].values.reshape(weather_df['平均気温(℃)'].shape[0],1))
scaler_x2 = MinMaxScaler()
x2 = scaler_x2.fit_transform(weather_df['日照時間(時間)'].values.reshape(weather_df['日照時間(時間)'].shape[0],1))

# %%
# 説明変数を格納
data_X = []
# 目的変数を格納
data_y = []
# 時数（どこまで過去のデータを考慮したいか）
p = 10
for i in range(len(weather_df)-p):
    data_X.append([x1[i:i+p].flatten(),x2[i:i+p].flatten()])
    data_y.append(x1[i+p])
    
data_X = np.array(data_X)
data_y = np.array(data_y)

# %%
# 訓練データとテストデータに分けます。
len_train = int(len(data_X)*0.7)

X_train = data_X[:len_train]
X_test = data_X[len_train:]
y_train = data_y[:len_train]
y_test = data_y[len_train:]

print(len(X_train),len(X_test))
# Out:
# 1271 546

# %%
# 時数（どこまで過去のデータを考慮したいか）
p = 10

# モデル定義
model = models.Sequential()
model.add(
    LSTM(
        100, 
        activation='tanh', 
        input_shape=(2, p)
    )
)
model.add(Dense(1,activation='linear'))

# 学習設定
model.compile(
    loss='mean_squared_error', 
    optimizer='adam', 
)

# %%
# モデルの学習
result = model.fit(
    X_train, 
    y_train, 
    batch_size=10, 
    epochs=100
)
# Out:
# Epoch 1/100
# 1271/1271 [==============================] - 1s 460us/step - loss: 0.0276
# Epoch 2/100
# 1271/1271 [==============================] - 0s 230us/step - loss: 0.0059
# Epoch 3/100
# 1271/1271 [==============================] - 0s 229us/step - loss: 0.0056
# Epoch 4/100
# 1271/1271 [==============================] - 0s 234us/step - loss: 0.0052
# Epoch 5/100
# 1271/1271 [==============================] - 0s 221us/step - loss: 0.0051
# Epoch 6/100
# 1271/1271 [==============================] - 0s 237us/step - loss: 0.0048
# Epoch 7/100
# 1271/1271 [==============================] - 0s 222us/step - loss: 0.0048
# Epoch 8/100
# 1271/1271 [==============================] - 0s 221us/step - loss: 0.0045
# Epoch 9/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0045
# Epoch 10/100
# 1271/1271 [==============================] - 0s 221us/step - loss: 0.0043
# Epoch 11/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0043
# Epoch 12/100
# 1271/1271 [==============================] - 0s 241us/step - loss: 0.0043
# Epoch 13/100
# 1271/1271 [==============================] - 0s 224us/step - loss: 0.0044
# Epoch 14/100
# 1271/1271 [==============================] - 0s 248us/step - loss: 0.0044
# Epoch 15/100
# 1271/1271 [==============================] - 0s 366us/step - loss: 0.0041
# Epoch 16/100
# 1271/1271 [==============================] - 0s 235us/step - loss: 0.0040
# Epoch 17/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0043
# Epoch 18/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0039
# Epoch 19/100
# 1271/1271 [==============================] - 0s 224us/step - loss: 0.0042
# Epoch 20/100
# 1271/1271 [==============================] - 0s 240us/step - loss: 0.0040
# Epoch 21/100
# 1271/1271 [==============================] - 0s 246us/step - loss: 0.0044
# Epoch 22/100
# 1271/1271 [==============================] - 0s 296us/step - loss: 0.0041
# Epoch 23/100
# 1271/1271 [==============================] - 0s 234us/step - loss: 0.0039
# Epoch 24/100
# 1271/1271 [==============================] - 0s 242us/step - loss: 0.0039
# Epoch 25/100
# 1271/1271 [==============================] - 0s 255us/step - loss: 0.0039
# Epoch 26/100
# 1271/1271 [==============================] - 0s 303us/step - loss: 0.0039
# Epoch 27/100
# 1271/1271 [==============================] - 0s 365us/step - loss: 0.0043
# Epoch 28/100
# 1271/1271 [==============================] - 0s 290us/step - loss: 0.0039
# Epoch 29/100
# 1271/1271 [==============================] - 0s 210us/step - loss: 0.0039
# Epoch 30/100
# 1271/1271 [==============================] - 0s 220us/step - loss: 0.0039
# Epoch 31/100
# 1271/1271 [==============================] - 0s 187us/step - loss: 0.0040
# Epoch 32/100
# 1271/1271 [==============================] - 0s 273us/step - loss: 0.0038
# Epoch 33/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0040 0s - loss: 0.00
# Epoch 34/100
# 1271/1271 [==============================] - 0s 220us/step - loss: 0.0038
# Epoch 35/100
# 1271/1271 [==============================] - 0s 212us/step - loss: 0.0039
# Epoch 36/100
# 1271/1271 [==============================] - 0s 250us/step - loss: 0.0040
# Epoch 37/100
# 1271/1271 [==============================] - 0s 199us/step - loss: 0.0038
# Epoch 38/100
# 1271/1271 [==============================] - 0s 201us/step - loss: 0.0038
# Epoch 39/100
# 1271/1271 [==============================] - 0s 225us/step - loss: 0.0038
# Epoch 40/100
# 1271/1271 [==============================] - 0s 190us/step - loss: 0.0039
# Epoch 41/100
# 1271/1271 [==============================] - 0s 190us/step - loss: 0.0039
# Epoch 42/100
# 1271/1271 [==============================] - 0s 199us/step - loss: 0.0039
# Epoch 43/100
# 1271/1271 [==============================] - 0s 304us/step - loss: 0.0036
# Epoch 44/100
# 1271/1271 [==============================] - 0s 342us/step - loss: 0.0039
# Epoch 45/100
# 1271/1271 [==============================] - 0s 344us/step - loss: 0.0037
# Epoch 46/100
# 1271/1271 [==============================] - 0s 262us/step - loss: 0.0037
# Epoch 47/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0040
# Epoch 48/100
# 1271/1271 [==============================] - 0s 248us/step - loss: 0.0037
# Epoch 49/100
# 1271/1271 [==============================] - 0s 250us/step - loss: 0.0038
# Epoch 50/100
# 1271/1271 [==============================] - 0s 356us/step - loss: 0.0036
# Epoch 51/100
# 1271/1271 [==============================] - 0s 308us/step - loss: 0.0038
# Epoch 52/100
# 1271/1271 [==============================] - 0s 229us/step - loss: 0.0038
# Epoch 53/100
# 1271/1271 [==============================] - 0s 257us/step - loss: 0.0036
# Epoch 54/100
# 1271/1271 [==============================] - 0s 186us/step - loss: 0.0036
# Epoch 55/100
# 1271/1271 [==============================] - 0s 196us/step - loss: 0.0040
# Epoch 56/100
# 1271/1271 [==============================] - 0s 225us/step - loss: 0.0036
# Epoch 57/100
# 1271/1271 [==============================] - 0s 195us/step - loss: 0.0037
# Epoch 58/100
# 1271/1271 [==============================] - 0s 236us/step - loss: 0.0037
# Epoch 59/100
# 1271/1271 [==============================] - 0s 211us/step - loss: 0.0037
# Epoch 60/100
# 1271/1271 [==============================] - 0s 269us/step - loss: 0.0039
# Epoch 61/100
# 1271/1271 [==============================] - 0s 270us/step - loss: 0.0037
# Epoch 62/100
# 1271/1271 [==============================] - 0s 348us/step - loss: 0.0038
# Epoch 63/100
# 1271/1271 [==============================] - 0s 344us/step - loss: 0.0036
# Epoch 64/100
# 1271/1271 [==============================] - 0s 240us/step - loss: 0.0036
# Epoch 65/100
# 1271/1271 [==============================] - 0s 257us/step - loss: 0.0035
# Epoch 66/100
# 1271/1271 [==============================] - 0s 302us/step - loss: 0.0038
# Epoch 67/100
# 1271/1271 [==============================] - 0s 286us/step - loss: 0.0036
# Epoch 68/100
# 1271/1271 [==============================] - 0s 235us/step - loss: 0.0037
# Epoch 69/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0037
# Epoch 70/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0036
# Epoch 71/100
# 1271/1271 [==============================] - 0s 232us/step - loss: 0.0037
# Epoch 72/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0036
# Epoch 73/100
# 1271/1271 [==============================] - 0s 220us/step - loss: 0.0037
# Epoch 74/100
# 1271/1271 [==============================] - 0s 230us/step - loss: 0.0036
# Epoch 75/100
# 1271/1271 [==============================] - 0s 228us/step - loss: 0.0035
# Epoch 76/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0037
# Epoch 77/100
# 1271/1271 [==============================] - 0s 228us/step - loss: 0.0036
# Epoch 78/100
# 1271/1271 [==============================] - 0s 217us/step - loss: 0.0036
# Epoch 79/100
# 1271/1271 [==============================] - 0s 234us/step - loss: 0.0035
# Epoch 80/100
# 1271/1271 [==============================] - 0s 230us/step - loss: 0.0035
# Epoch 81/100
# 1271/1271 [==============================] - 0s 228us/step - loss: 0.0037
# Epoch 82/100
# 1271/1271 [==============================] - 0s 253us/step - loss: 0.0036
# Epoch 83/100
# 1271/1271 [==============================] - 0s 235us/step - loss: 0.0036
# Epoch 84/100
# 1271/1271 [==============================] - 0s 235us/step - loss: 0.0035
# Epoch 85/100
# 1271/1271 [==============================] - 0s 255us/step - loss: 0.0035
# Epoch 86/100
# 1271/1271 [==============================] - 0s 283us/step - loss: 0.0035
# Epoch 87/100
# 1271/1271 [==============================] - 0s 239us/step - loss: 0.0035
# Epoch 88/100
# 1271/1271 [==============================] - 0s 241us/step - loss: 0.0037
# Epoch 89/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0035
# Epoch 90/100
# 1271/1271 [==============================] - 0s 255us/step - loss: 0.0035
# Epoch 91/100
# 1271/1271 [==============================] - 0s 289us/step - loss: 0.0036
# Epoch 92/100
# 1271/1271 [==============================] - 0s 227us/step - loss: 0.0037
# Epoch 93/100
# 1271/1271 [==============================] - 0s 233us/step - loss: 0.0036
# Epoch 94/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0034
# Epoch 95/100
# 1271/1271 [==============================] - 0s 251us/step - loss: 0.0034
# Epoch 96/100
# 1271/1271 [==============================] - 0s 253us/step - loss: 0.0035
# Epoch 97/100
# 1271/1271 [==============================] - 0s 217us/step - loss: 0.0035
# Epoch 98/100
# 1271/1271 [==============================] - 0s 274us/step - loss: 0.0036
# Epoch 99/100
# 1271/1271 [==============================] - 0s 286us/step - loss: 0.0035
# Epoch 100/100
# 1271/1271 [==============================] - 0s 231us/step - loss: 0.0035

# %%
# 予測
y_prediction = model.predict(X_test).flatten()

plt.plot(y_prediction, label='予測値')
plt.plot(y_test, label='実測値')
plt.legend()

# %%
# 乖離度
print(
    np.mean(
        np.abs(y_prediction-y_test.flatten())
        /y_test
    )
)
# Out:
# 0.13304802001770796
